# %%
import pandas as pd
import numpy as np

from ipyvizzu import Chart, Data, Config, Style
from ipyvizzustory import Story, Slide, Step

#Create data object, read csv to data frame and add data frame to data object.
data = Data()

df = pd.read_csv("./premier-league.csv", dtype={"year": str})

#Rename columns
df.rename(columns={"fee": "fee_raw", "fee_cleaned": "fee[m€]"}, inplace = True)

# # convert 'Age' from float to int
df['age'] = df['age'].fillna(0)
df['age'] = df['age'].astype(int)

df['fee[m€]'] = df['fee[m€]'].fillna(0)

# #add negative fee for players boughm€t
df['inorout'] = np.where(df['transfer_movement'] == 'in', -1, 1)
df['fee_real[m€]'] = df['fee[m€]'] * df['inorout']

#categorize transfers (purchase, loan, end of loan, other)

#sort by club_name
df.sort_values(by=['club_name','year'], inplace=True)
df.head(10)
# Out:
#              club_name     player_name  age        position  \
# 18171  AFC Bournemouth    Tyrone Mings   22     Centre-Back
# 18172  AFC Bournemouth      Max Gradel   27     Left Winger
# 18173  AFC Bournemouth    Glenn Murray   31  Centre-Forward
# 18174  AFC Bournemouth      Lee Tomlin   26  Second Striker
# 18175  AFC Bournemouth     Artur Boruc   35      Goalkeeper
# 18176  AFC Bournemouth  Sylvain Distin   37     Centre-Back
# 18177  AFC Bournemouth     Joshua King   23  Second Striker
# 18178  AFC Bournemouth   Adam Federici   30      Goalkeeper
# 18179  AFC Bournemouth    Jordan Green   20    Right Winger
# 18180  AFC Bournemouth  Christian Atsu   23     Left Winger
#
#       club_involved_name        fee_raw transfer_movement transfer_period  \
# 18171            Ipswich        €11.30m                in          Summer
# 18172      Saint-Étienne        €10.00m                in          Summer
# 18173     Crystal Palace         €5.40m                in          Summer
# 18174      Middlesbrough         €4.30m                in          Summer
# 18175        Southampton  free transfer                in          Summer
# 18176            Everton  free transfer                in          Summer
# 18177          Blackburn  free transfer                in          Summer
# 18178            Reading  free transfer                in          Summer
# 18179            Banbury  free transfer                in          Summer
# 18180            Chelsea  loan transfer                in          Summer
#
#        fee[m€]     league_name  year     season  country  inorout  \
# 18171     11.3  Premier League  2015  2015/2016  England       -1
# 18172     10.0  Premier League  2015  2015/2016  England       -1
# 18173      5.4  Premier League  2015  2015/2016  England       -1
# 18174      4.3  Premier League  2015  2015/2016  England       -1
# 18175      0.0  Premier League  2015  2015/2016  England       -1
# 18176      0.0  Premier League  2015  2015/2016  England       -1
# 18177      0.0  Premier League  2015  2015/2016  England       -1
# 18178      0.0  Premier League  2015  2015/2016  England       -1
# 18179      0.0  Premier League  2015  2015/2016  England       -1
# 18180      0.0  Premier League  2015  2015/2016  England       -1
#
#        fee_real[m€]
# 18171         -11.3
# 18172         -10.0
# 18173          -5.4
# 18174          -4.3
# 18175          -0.0
# 18176          -0.0
# 18177          -0.0
# 18178          -0.0
# 18179          -0.0
# 18180          -0.0

# %%
df.dtypes
# Out:
# club_name              object
# player_name            object
# age                     int32
# position               object
# club_involved_name     object
# fee_raw                object
# transfer_movement      object
# transfer_period        object
# fee[m€]               float64
# league_name            object
# year                   object
# season                 object
# country                object
# inorout                 int32
# fee_real[m€]          float64
# dtype: object

# %%
df.club_name.nunique()
# Out:
# 50

# %%
len(df.index)

# %%
#check against transfermarkt data
filtered_values = np.where((df['year'] == '2020') & (df['club_name'] == 'Arsenal FC') & (df['transfer_movement'] == 'in'))
display(df.loc[filtered_values])
# Out:
#         club_name             player_name  age            position  \
# 21598  Arsenal FC           Thomas Partey   27  Defensive Midfield
# 21599  Arsenal FC       Gabriel Magalhães   22         Centre-Back
# 21600  Arsenal FC              Pablo Marí   26         Centre-Back
# 21601  Arsenal FC    Rúnar Alex Rúnarsson   25          Goalkeeper
# 21602  Arsenal FC           Cédric Soares   28          Right-Back
# 21603  Arsenal FC                 Willian   32         Left Winger
# 21604  Arsenal FC        Emile Smith Rowe   20  Attacking Midfield
# 21605  Arsenal FC             Joe Willock   21    Central Midfield
# 21606  Arsenal FC          William Saliba   19         Centre-Back
# 21607  Arsenal FC  Ainsley Maitland-Niles   23      Right Midfield
# 21608  Arsenal FC             Dejan Iliev   25          Goalkeeper
# 21609  Arsenal FC      Henrikh Mkhitaryan   31  Attacking Midfield
# 21610  Arsenal FC          Mohamed Elneny   28  Defensive Midfield
# 22152  Arsenal FC         Martin Ødegaard   22  Attacking Midfield
# 22153  Arsenal FC             Mathew Ryan   28          Goalkeeper
# 22154  Arsenal FC             Dejan Iliev   25          Goalkeeper
#
#       club_involved_name                  fee_raw transfer_movement  \
# 21598    Atlético Madrid                  €50.00m                in
# 21599         LOSC Lille                  €26.00m                in
# 21600           Flamengo                   €6.00m                in
# 21601              Dijon                   €2.00m                in
# 21602        Southampton            free transfer                in
# 21603            Chelsea            free transfer                in
# 21604        Arsenal U23                        -                in
# 21605          Newcastle  End of loanMay 31, 2021                in
# 21606      Saint-Étienne  End of loanJun 30, 2020                in
# 21607          West Brom  End of loanMay 31, 2021                in
# 21608        Jagiellonia  End of loanJul 31, 2020                in
# 21609            AS Roma  End of loanAug 31, 2020                in
# 21610           Besiktas   End of loanAug 3, 2020                in
# 22152        Real Madrid          Loan fee:€2.00m                in
# 22153           Brighton            loan transfer                in
# 22154         Shrewsbury  End of loanJan 31, 2021                in
#
#       transfer_period  fee[m€]     league_name  year     season  country  \
# 21598          Summer     50.0  Premier League  2020  2020/2021  England
# 21599          Summer     26.0  Premier League  2020  2020/2021  England
# 21600          Summer      6.0  Premier League  2020  2020/2021  England
# 21601          Summer      2.0  Premier League  2020  2020/2021  England
# 21602          Summer      0.0  Premier League  2020  2020/2021  England
# 21603          Summer      0.0  Premier League  2020  2020/2021  England
# 21604          Summer      0.0  Premier League  2020  2020/2021  England
# 21605          Summer      0.0  Premier League  2020  2020/2021  England
# 21606          Summer      0.0  Premier League  2020  2020/2021  England
# 21607          Summer      0.0  Premier League  2020  2020/2021  England
# 21608          Summer      0.0  Premier League  2020  2020/2021  England
# 21609          Summer      0.0  Premier League  2020  2020/2021  England
# 21610          Summer      0.0  Premier League  2020  2020/2021  England
# 22152          Winter      2.0  Premier League  2020  2020/2021  England
# 22153          Winter      0.0  Premier League  2020  2020/2021  England
# 22154          Winter      0.0  Premier League  2020  2020/2021  England
#
#        inorout  fee_real[m€]
# 21598       -1         -50.0
# 21599       -1         -26.0
# 21600       -1          -6.0
# 21601       -1          -2.0
# 21602       -1          -0.0
# 21603       -1          -0.0
# 21604       -1          -0.0
# 21605       -1          -0.0
# 21606       -1          -0.0
# 21607       -1          -0.0
# 21608       -1          -0.0
# 21609       -1          -0.0
# 21610       -1          -0.0
# 22152       -1          -2.0
# 22153       -1          -0.0
# 22154       -1          -0.0

# %%
#stringszűrős példa
filtered_values = np.where((dataFrame['Salary']>=100000) & (dataFrame['Age']< 40) & (dataFrame['JOB'].str.startswith('D')))
print(filtered_values)
display(dataFrame.loc[filtered_values])

# %%
df.to_csv("football_transfers_cleaned.csv")
